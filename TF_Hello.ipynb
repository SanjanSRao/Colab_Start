# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanSRao/Colab_Start/blob/GDEV_TF/TF_Hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# STEP 1: Create NN
#
# STEP 2: Define and compile the network
#         a) Loss function
#         b) Optimizer
#
# STEP 3: Provide Data
#
# STEP 4: Train Neural Network
#
# STEP 5: Use model

# %%
model = keras.Sequential([
                          keras.layers.Dense(units=1, input_shape=[1])
                         ])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 4ms/step - loss: 87.6162
# Epoch 2/500
# 1/1 [==============================] - 0s 891us/step - loss: 68.9370
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 54.2410
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 42.6788
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 33.5821
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 26.4252
# Epoch 7/500
# 1/1 [==============================] - 0s 793us/step - loss: 20.7943
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 16.3642
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 12.8787
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 10.1364
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.9788
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[30.997408]]

# %% [markdown]
# As you work with neural networks, you'll see that pattern recurring. You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.
